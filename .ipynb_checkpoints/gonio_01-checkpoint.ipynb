# %% [markdown]
# ### Goniometrické funkce
# lorem ipsum

# %% [markdown]
# #### Importování balíků a zavedení funkcí

# %%
import numpy as np
from numpy import sin,cos,tan,arcsin,arccos,arctan,exp,pi
import matplotlib.pyplot as plt

x = np.arange(-2*pi,+2*pi,0.01)
y = x

def nakresli_y():   
    plt.plot(x,y,'-')
    plt.grid()
    
def nakresli_sinus():
    plt.plot(x,sin(x),'-')

# %%
print('Graf')
y = x + 0*x**2 + 0*x**3 + 0*x**4 + 0*x**5
nakresli_y()
nakresli_sinus()
# Out:
# Graf
