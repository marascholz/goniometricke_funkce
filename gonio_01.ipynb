# %% [markdown]
# ### Goniometrické funkce
# lorem ipsum

# %% [markdown]
# #### Importování balíků a zavedení funkcí

# %%
import numpy as np
from numpy import sin,cos,tan,arcsin,arccos,arctan,exp,pi
import matplotlib.pyplot as plt

x = np.arange(-2*pi,+2*pi,0.01)
y = x

def nakresli_y():   
    plt.plot(x,y,'-')
    plt.grid()
    
def nakresli_sinus():
    plt.plot(x,sin(x),'-')
    plt.ylim([-2,2])

# %%
print('Graf')
y = x - 1/(3*2)*x**3 + 1/(5*4*3*2)*x**5 - 1/(7*6*5*4*3*2)*x**7 
nakresli_y()
nakresli_sinus()
# Out:
# Graf
